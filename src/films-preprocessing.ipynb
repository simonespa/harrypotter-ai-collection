# %%
# import pymupdf

# doc = pymupdf.open('data/films/1-harry-potter-and-the-sorcerers-stone-2001.pdf')
# with open('output.txt', 'wb') as file:
#     for page in doc:
#         # text = doc[1].get_text(option='blocks')
#         text = page.get_text(option='text').encode("utf8")
#         file.write(text)
#         file.write(bytes((12,)))
